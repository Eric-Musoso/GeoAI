# %% [markdown]
# # Visualizing Planet Tanager Data Interactively with HyperCoast
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/HyperCoast/blob/main/docs/examples/tanager.ipynb)
#
#
# This notebook demonstrates how to visualize the [Planet Tanager hyperspectral data](https://www.planet.com/data/stac/browser/tanager-core-imagery/catalog.json) interactively with HyperCoast.
#
#
# Tanager-1 (launched August 2024) carries a high-precision Dyson imaging spectrometer onboard Planet’s next-generation smallsat bus. Tanager provides high spectral resolution (~5 nm) across the full 380–2500 nm VSWIR spectral range. For more details, please refer to the [Planet Tanager data release page](https://www.planet.com/pulse/unleash-the-power-of-hyperspectral-over-50-tanager-radiance-datasets-now-available-on-planet-s).

# %% [markdown]
# ## Install packages
#
# Uncomment the following line to install the packages.

# %%
# %pip install hypercoast
# Out:
# Collecting hypercoast
#   Downloading hypercoast-0.11.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: dask in /usr/local/lib/python3.11/dist-packages (from hypercoast) (2025.5.0)
# Collecting earthaccess (from hypercoast)
#   Downloading earthaccess-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.11/dist-packages (from hypercoast) (1.0.1)
# Requirement already satisfied: h5netcdf in /usr/local/lib/python3.11/dist-packages (from hypercoast) (1.6.3)
# Collecting hvplot (from hypercoast)
#   Downloading hvplot-0.11.3-py3-none-any.whl.metadata (15 kB)
# Collecting leafmap>=0.38.0 (from hypercoast)
#   Downloading leafmap-0.48.6-py2.py3-none-any.whl.metadata (16 kB)
# Collecting localtileserver (from hypercoast)
#   Downloading localtileserver-0.10.6-py3-none-any.whl.metadata (5.2 kB)
# Collecting mapclassify (from hypercoast)
#   Downloading mapclassify-2.10.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting netcdf4 (from hypercoast)
#   Downloading netCDF4-1.7.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from hypercoast) (2.0.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from hypercoast) (5.9.5)
# Collecting rioxarray (from hypercoast)
#   Downloading rioxarray-0.19.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting s3fs (from hypercoast)
#   Downloading s3fs-2025.7.0-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from hypercoast) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from hypercoast) (1.15.3)
# Requirement already satisfied: xarray in /usr/local/lib/python3.11/dist-packages (from hypercoast) (2025.3.1)
# Collecting anywidget (from leafmap>=0.38.0->hypercoast)
#   Downloading anywidget-0.9.18-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.11/dist-packages (from leafmap>=0.38.0->hypercoast) (0.12.45)
# Requirement already satisfied: duckdb in /usr/local/lib/python3.11/dist-packages (from leafmap>=0.38.0->hypercoast) (1.2.2)
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (from leafmap>=0.38.0->hypercoast) (0.19.7)
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (from leafmap>=0.38.0->hypercoast) (5.2.0)
# Collecting geojson (from leafmap>=0.38.0->hypercoast)
#   Downloading geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.11/dist-packages (from leafmap>=0.38.0->hypercoast) (2.0.2)
# Requirement already satisfied: ipyfilechooser in /usr/local/lib/python3.11/dist-packages (from leafmap>=0.38.0->hypercoast) (0.6.0)
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.11/dist-packages (from leafmap>=0.38.0->hypercoast) (0.20.0)
# Collecting ipyvuetify (from leafmap>=0.38.0->hypercoast)
#   Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.11/dist-packages (from leafmap>=0.38.0->hypercoast) (7.7.1)
# Collecting maplibre (from leafmap>=0.38.0->hypercoast)
#   Downloading maplibre-0.3.4-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from leafmap>=0.38.0->hypercoast) (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from leafmap>=0.38.0->hypercoast) (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from leafmap>=0.38.0->hypercoast) (5.24.1)
# Collecting pystac-client (from leafmap>=0.38.0->hypercoast)
#   Downloading pystac_client-0.9.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: python-box in /usr/local/lib/python3.11/dist-packages (from leafmap>=0.38.0->hypercoast) (7.3.2)
# Requirement already satisfied: scooby in /usr/local/lib/python3.11/dist-packages (from leafmap>=0.38.0->hypercoast) (0.10.1)
# Collecting whiteboxgui (from leafmap>=0.38.0->hypercoast)
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from leafmap>=0.38.0->hypercoast) (2025.4.0)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask->hypercoast) (8.2.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dask->hypercoast) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask->hypercoast) (2025.3.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from dask->hypercoast) (25.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask->hypercoast) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from dask->hypercoast) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from dask->hypercoast) (0.12.1)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask->hypercoast) (8.7.0)
# Requirement already satisfied: importlib-resources>=6.3.2 in /usr/local/lib/python3.11/dist-packages (from earthaccess->hypercoast) (6.5.2)
# Collecting multimethod>=1.8 (from earthaccess->hypercoast)
#   Downloading multimethod-2.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting pqdm>=0.1 (from earthaccess->hypercoast)
#   Downloading pqdm-0.2.0-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting python-cmr>=0.10.0 (from earthaccess->hypercoast)
#   Downloading python_cmr-0.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.11/dist-packages (from earthaccess->hypercoast) (2.32.3)
# Collecting tinynetrc>=1.3.1 (from earthaccess->hypercoast)
#   Downloading tinynetrc-1.3.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from earthaccess->hypercoast) (4.14.1)
# Collecting aiobotocore<3.0.0,>=2.5.4 (from s3fs->hypercoast)
#   Downloading aiobotocore-2.23.1-py3-none-any.whl.metadata (25 kB)
# Collecting fsspec>=2021.09.0 (from dask->hypercoast)
#   Downloading fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from s3fs->hypercoast) (3.11.15)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas->hypercoast) (0.11.0)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from geopandas->hypercoast) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from geopandas->hypercoast) (2.1.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from h5netcdf->hypercoast) (3.14.0)
# Requirement already satisfied: bokeh>=3.1 in /usr/local/lib/python3.11/dist-packages (from hvplot->hypercoast) (3.7.3)
# Requirement already satisfied: colorcet>=2 in /usr/local/lib/python3.11/dist-packages (from hvplot->hypercoast) (3.1.0)
# Requirement already satisfied: holoviews>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from hvplot->hypercoast) (1.21.0)
# Requirement already satisfied: panel>=1.0 in /usr/local/lib/python3.11/dist-packages (from hvplot->hypercoast) (1.7.4)
# Requirement already satisfied: param<3.0,>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from hvplot->hypercoast) (2.2.1)
# Requirement already satisfied: flask<4,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from localtileserver->hypercoast) (3.1.1)
# Collecting Flask-Caching (from localtileserver->hypercoast)
#   Downloading Flask_Caching-2.3.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting flask-cors (from localtileserver->hypercoast)
#   Downloading flask_cors-6.0.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting flask-restx>=1.3.0 (from localtileserver->hypercoast)
#   Downloading flask_restx-1.3.0-py2.py3-none-any.whl.metadata (9.3 kB)
# Collecting rio-tiler (from localtileserver->hypercoast)
#   Downloading rio_tiler-7.8.1-py3-none-any.whl.metadata (12 kB)
# Collecting rio-cogeo (from localtileserver->hypercoast)
#   Downloading rio_cogeo-5.4.2-py3-none-any.whl.metadata (4.7 kB)
# Collecting server-thread (from localtileserver->hypercoast)
#   Downloading server_thread-0.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.11/dist-packages (from localtileserver->hypercoast) (3.1.3)
# Requirement already satisfied: networkx>=3.2 in /usr/local/lib/python3.11/dist-packages (from mapclassify->hypercoast) (3.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->hypercoast) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->hypercoast) (3.6.0)
# Collecting cftime (from netcdf4->hypercoast)
#   Downloading cftime-1.6.4.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from netcdf4->hypercoast) (2025.7.14)
# Collecting rasterio>=1.4.3 (from rioxarray->hypercoast)
#   Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs->hypercoast)
#   Downloading aioitertools-0.12.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting botocore<1.38.47,>=1.38.40 (from aiobotocore<3.0.0,>=2.5.4->s3fs->hypercoast)
#   Downloading botocore-1.38.46-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->hypercoast) (2.9.0.post0)
# Collecting jmespath<2.0.0,>=0.7.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs->hypercoast)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->hypercoast) (6.6.3)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /usr/local/lib/python3.11/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->hypercoast) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->hypercoast) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->hypercoast) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->hypercoast) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->hypercoast) (1.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->hypercoast) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->hypercoast) (1.20.1)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.1->hvplot->hypercoast) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.1->hvplot->hypercoast) (1.3.2)
# Requirement already satisfied: narwhals>=1.13 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.1->hvplot->hypercoast) (1.47.1)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.1->hvplot->hypercoast) (11.2.1)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.1->hvplot->hypercoast) (6.4.2)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from flask<4,>=2.0.0->localtileserver->hypercoast) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from flask<4,>=2.0.0->localtileserver->hypercoast) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from flask<4,>=2.0.0->localtileserver->hypercoast) (3.0.2)
# Collecting aniso8601>=0.82 (from flask-restx>=1.3.0->localtileserver->hypercoast)
#   Downloading aniso8601-10.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from flask-restx>=1.3.0->localtileserver->hypercoast) (4.24.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from flask-restx>=1.3.0->localtileserver->hypercoast) (2025.2)
# Requirement already satisfied: pyviz-comms>=2.1 in /usr/local/lib/python3.11/dist-packages (from holoviews>=1.19.0->hvplot->hypercoast) (3.0.6)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata>=4.13.0->dask->hypercoast) (3.23.0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->leafmap>=0.38.0->hypercoast) (2025.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from panel>=1.0->hvplot->hypercoast) (6.2.0)
# Requirement already satisfied: linkify-it-py in /usr/local/lib/python3.11/dist-packages (from panel>=1.0->hvplot->hypercoast) (2.0.3)
# Requirement already satisfied: markdown in /usr/local/lib/python3.11/dist-packages (from panel>=1.0->hvplot->hypercoast) (3.8.2)
# Requirement already satisfied: markdown-it-py in /usr/local/lib/python3.11/dist-packages (from panel>=1.0->hvplot->hypercoast) (3.0.0)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.11/dist-packages (from panel>=1.0->hvplot->hypercoast) (0.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from panel>=1.0->hvplot->hypercoast) (4.67.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.11/dist-packages (from partd>=1.4.0->dask->hypercoast) (1.0.0)
# Collecting bounded-pool-executor (from pqdm>=0.1->earthaccess->hypercoast)
#   Downloading bounded_pool_executor-0.0.3-py3-none-any.whl.metadata (2.7 kB)
# Collecting affine (from rasterio>=1.4.3->rioxarray->hypercoast)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting cligj>=0.5 (from rasterio>=1.4.3->rioxarray->hypercoast)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting click-plugins (from rasterio>=1.4.3->rioxarray->hypercoast)
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from rasterio>=1.4.3->rioxarray->hypercoast) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26->earthaccess->hypercoast) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26->earthaccess->hypercoast) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26->earthaccess->hypercoast) (2.4.0)
# Collecting psygnal>=0.8.1 (from anywidget->leafmap>=0.38.0->hypercoast)
#   Downloading psygnal-0.14.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->leafmap>=0.38.0->hypercoast) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->leafmap>=0.38.0->hypercoast) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->leafmap>=0.38.0->hypercoast) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->leafmap>=0.38.0->hypercoast) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->leafmap>=0.38.0->hypercoast) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->leafmap>=0.38.0->hypercoast) (3.0.15)
# Requirement already satisfied: traittypes>=0.0.6 in /usr/local/lib/python3.11/dist-packages (from bqplot->leafmap>=0.38.0->hypercoast) (0.2.1)
# Collecting cachelib>=0.9.0 (from Flask-Caching->localtileserver->hypercoast)
#   Downloading cachelib-0.13.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium->leafmap>=0.38.0->hypercoast) (0.8.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown->leafmap>=0.38.0->hypercoast) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown->leafmap>=0.38.0->hypercoast) (3.18.0)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in /usr/local/lib/python3.11/dist-packages (from ipyleaflet->leafmap>=0.38.0->hypercoast) (0.20.0)
# Collecting ipyvue<2,>=1.7 (from ipyvuetify->leafmap>=0.38.0->hypercoast)
#   Downloading ipyvue-1.11.2-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting eval-type-backport (from maplibre->leafmap>=0.38.0->hypercoast)
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: pydantic>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from maplibre->leafmap>=0.38.0->hypercoast) (2.11.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->leafmap>=0.38.0->hypercoast) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->leafmap>=0.38.0->hypercoast) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->leafmap>=0.38.0->hypercoast) (1.4.8)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->leafmap>=0.38.0->hypercoast) (8.5.0)
# Collecting pystac>=1.10.0 (from pystac[validation]>=1.10.0->pystac-client->leafmap>=0.38.0->hypercoast)
#   Downloading pystac-1.13.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting morecantile<7.0,>=5.0 (from rio-cogeo->localtileserver->hypercoast)
#   Downloading morecantile-6.2.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from rio-tiler->localtileserver->hypercoast) (5.5.2)
# Collecting color-operations (from rio-tiler->localtileserver->hypercoast)
#   Downloading color_operations-0.2.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from rio-tiler->localtileserver->hypercoast) (0.28.1)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.11/dist-packages (from rio-tiler->localtileserver->hypercoast) (2.11.0)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.11/dist-packages (from server-thread->localtileserver->hypercoast) (0.35.0)
# Requirement already satisfied: ipytree in /usr/local/lib/python3.11/dist-packages (from whiteboxgui->leafmap>=0.38.0->hypercoast) (0.2.2)
# Collecting whitebox (from whiteboxgui->leafmap>=0.38.0->hypercoast)
#   Downloading whitebox-2.3.6-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap>=0.38.0->hypercoast) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap>=0.38.0->hypercoast) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap>=0.38.0->hypercoast) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap>=0.38.0->hypercoast) (1.6.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap>=0.38.0->hypercoast) (24.0.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap>=0.38.0->hypercoast) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->leafmap>=0.38.0->hypercoast)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap>=0.38.0->hypercoast) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap>=0.38.0->hypercoast) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap>=0.38.0->hypercoast) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap>=0.38.0->hypercoast) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap>=0.38.0->hypercoast) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap>=0.38.0->hypercoast) (4.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.5.3->maplibre->leafmap>=0.38.0->hypercoast) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.5.3->maplibre->leafmap>=0.38.0->hypercoast) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.5.3->maplibre->leafmap>=0.38.0->hypercoast) (0.4.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->flask-restx>=1.3.0->localtileserver->hypercoast) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->flask-restx>=1.3.0->localtileserver->hypercoast) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->flask-restx>=1.3.0->localtileserver->hypercoast) (0.26.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore<3.0.0,>=2.5.4->s3fs->hypercoast) (1.17.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (6.5.7)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown->leafmap>=0.38.0->hypercoast) (2.7)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach->panel>=1.0->hvplot->hypercoast) (0.5.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->rio-tiler->localtileserver->hypercoast) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->rio-tiler->localtileserver->hypercoast) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->rio-tiler->localtileserver->hypercoast) (0.16.0)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.11/dist-packages (from linkify-it-py->panel>=1.0->hvplot->hypercoast) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py->panel>=1.0->hvplot->hypercoast) (0.1.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->leafmap>=0.38.0->hypercoast) (1.7.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->leafmap>=0.38.0->hypercoast) (0.8.4)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->leafmap>=0.38.0->hypercoast) (5.8.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (0.22.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (1.3.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->leafmap>=0.38.0->hypercoast) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->leafmap>=0.38.0->hypercoast) (0.2.13)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx->rio-tiler->localtileserver->hypercoast) (1.3.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->leafmap>=0.38.0->hypercoast) (4.3.8)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (0.2.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (2.21.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (21.2.0)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (2.22)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.38.0->hypercoast) (1.8.0)
# Downloading hypercoast-0.11.1-py2.py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.7 MB/s eta 0:00:00
# Downloading leafmap-0.48.6-py2.py3-none-any.whl (568 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.1/568.1 kB 11.9 MB/s eta 0:00:00
# Downloading earthaccess-0.14.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 4.0 MB/s eta 0:00:00
# Downloading s3fs-2025.7.0-py3-none-any.whl (30 kB)
# Downloading fsspec-2025.7.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.6/199.6 kB 11.8 MB/s eta 0:00:00
# Downloading hvplot-0.11.3-py3-none-any.whl (170 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.3/170.3 kB 11.0 MB/s eta 0:00:00
# Downloading localtileserver-0.10.6-py3-none-any.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 68.7 MB/s eta 0:00:00
# Downloading mapclassify-2.10.0-py3-none-any.whl (882 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.2/882.2 kB 38.2 MB/s eta 0:00:00
# Downloading netCDF4-1.7.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 76.0 MB/s eta 0:00:00
# Downloading rioxarray-0.19.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 kB 4.1 MB/s eta 0:00:00
# Downloading aiobotocore-2.23.1-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.2/84.2 kB 5.4 MB/s eta 0:00:00
# Downloading flask_restx-1.3.0-py2.py3-none-any.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 59.8 MB/s eta 0:00:00
# Downloading multimethod-2.0-py3-none-any.whl (9.8 kB)
# Downloading pqdm-0.2.0-py2.py3-none-any.whl (6.8 kB)
# Downloading python_cmr-0.13.0-py3-none-any.whl (14 kB)
# Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 61.5 MB/s eta 0:00:00
# Downloading tinynetrc-1.3.1-py2.py3-none-any.whl (3.9 kB)
# Downloading anywidget-0.9.18-py3-none-any.whl (220 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.7/220.7 kB 12.6 MB/s eta 0:00:00
# Downloading cftime-1.6.4.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 49.7 MB/s eta 0:00:00
# Downloading Flask_Caching-2.3.1-py3-none-any.whl (28 kB)
# Downloading flask_cors-6.0.1-py3-none-any.whl (13 kB)
# Downloading geojson-3.2.0-py3-none-any.whl (15 kB)
# Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 72.4 MB/s eta 0:00:00
# Downloading maplibre-0.3.4-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 44.9 MB/s eta 0:00:00
# Downloading pystac_client-0.9.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.5 MB/s eta 0:00:00
# Downloading rio_cogeo-5.4.2-py3-none-any.whl (21 kB)
# Downloading rio_tiler-7.8.1-py3-none-any.whl (269 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.1/269.1 kB 15.6 MB/s eta 0:00:00
# Downloading server_thread-0.3.0-py3-none-any.whl (6.6 kB)
# Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 6.4 MB/s eta 0:00:00
# Downloading aioitertools-0.12.0-py3-none-any.whl (24 kB)
# Downloading aniso8601-10.0.1-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 3.1 MB/s eta 0:00:00
# Downloading botocore-1.38.46-py3-none-any.whl (13.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 65.8 MB/s eta 0:00:00
# Downloading cachelib-0.13.0-py3-none-any.whl (20 kB)
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading ipyvue-1.11.2-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 62.8 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading morecantile-6.2.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 2.9 MB/s eta 0:00:00
# Downloading psygnal-0.14.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (837 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 837.4/837.4 kB 4.1 MB/s eta 0:00:00
# Downloading pystac-1.13.0-py3-none-any.whl (206 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.8/206.8 kB 11.2 MB/s eta 0:00:00
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading bounded_pool_executor-0.0.3-py3-none-any.whl (3.4 kB)
# Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Downloading color_operations-0.2.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (195 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.2/195.2 kB 12.0 MB/s eta 0:00:00
# Downloading eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Downloading whitebox-2.3.6-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 5.0 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 55.0 MB/s eta 0:00:00
# Installing collected packages: tinynetrc, bounded-pool-executor, aniso8601, whitebox, psygnal, pqdm, multimethod, jmespath, jedi, geojson, fsspec, eval-type-backport, color-operations, cligj, click-plugins, cftime, cachelib, aioitertools, affine, server-thread, rasterio, python-cmr, pystac, netcdf4, botocore, morecantile, maplibre, mapclassify, flask-cors, Flask-Caching, aiobotocore, s3fs, rioxarray, rio-tiler, rio-cogeo, flask-restx, pystac-client, localtileserver, earthaccess, hvplot, ipyvue, anywidget, whiteboxgui, ipyvuetify, leafmap, hypercoast
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.7.0 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# Successfully installed Flask-Caching-2.3.1 affine-2.4.0 aiobotocore-2.23.1 aioitertools-0.12.0 aniso8601-10.0.1 anywidget-0.9.18 botocore-1.38.46 bounded-pool-executor-0.0.3 cachelib-0.13.0 cftime-1.6.4.post1 click-plugins-1.1.1.2 cligj-0.7.2 color-operations-0.2.0 earthaccess-0.14.0 eval-type-backport-0.2.2 flask-cors-6.0.1 flask-restx-1.3.0 fsspec-2025.7.0 geojson-3.2.0 hvplot-0.11.3 hypercoast-0.11.1 ipyvue-1.11.2 ipyvuetify-1.11.3 jedi-0.19.2 jmespath-1.0.1 leafmap-0.48.6 localtileserver-0.10.6 mapclassify-2.10.0 maplibre-0.3.4 morecantile-6.2.0 multimethod-2.0 netcdf4-1.7.2 pqdm-0.2.0 psygnal-0.14.0 pystac-1.13.0 pystac-client-0.9.0 python-cmr-0.13.0 rasterio-1.4.3 rio-cogeo-5.4.2 rio-tiler-7.8.1 rioxarray-0.19.0 s3fs-2025.7.0 server-thread-0.3.0 tinynetrc-1.3.1 whitebox-2.3.6 whiteboxgui-2.3.0

# %% [markdown]
# ## Import libraries

# %%
import hypercoast

# %% [markdown]
# ## Find Tanager data
#
# Browse the Tanager data on the [Planet STAC browser](https://www.planet.com/data/stac/browser/tanager-core-imagery/catalog.json?.language=en). Find the data you want to visualize.
#
# For example, we want to visualize the data of the [coastal water bodies in the San Francisco Bay area](https://www.planet.com/data/stac/browser/tanager-core-imagery/coastal-water-bodies/20250514_193937_64_4001/20250514_193937_64_4001.json?.asset=asset-basic_radiance_hdf5).
# Click on the "Copy URL" button to get the direct URL of the data.
#
# ![](https://github.com/user-attachments/assets/c0107919-c36a-4d92-9886-2701b282ff5c)

# %% [markdown]
# ## Download Tanager data
#
# Once you have the URL of the data, you can download the data using the following code:

# %%
url = "https://storage.googleapis.com/open-cogs/planet-stac/release1-basic-radiance/20250503_112046_16_4001_basic_radiance.h5"

# %%
file_path = hypercoast.download_file(url)

# %% [markdown]
# ## Read Tanager data
#
# We can read the Tanager data using the `read_tanager` function. It will return a `xarray.Dataset` object. The `toa_radiance` variable is the top of atmosphere radiance. It has 426 spectral bands. Note that the dataset is not gridded. We will need to interpolate the data to a regular grid for visualization on an interactive map.

# %%
dataset = hypercoast.read_tanager(file_path)
dataset
# Out:
# <xarray.Dataset> Size: 523MB
# Dimensions:       (wavelength: 426, y: 501, x: 607)
# Coordinates:
#   * wavelength    (wavelength) float64 3kB 376.4 381.4 ... 2.494e+03 2.499e+03
#     fwhm          (wavelength) float64 3kB 5.39 5.42 5.45 5.48 ... 5.21 5.2 5.2
#     latitude      (y, x) float64 2MB 52.34 52.34 52.34 ... 52.16 52.16 52.16
#     longitude     (y, x) float64 2MB 5.134 5.134 5.135 ... 5.367 5.368 5.368
# Dimensions without coordinates: y, x
# Data variables:
#     toa_radiance  (wavelength, y, x) float32 518MB 59.58 58.1 ... 0.1049 0.09438
# Attributes:
#     source:     Planet Tanager HDF5
#     stac_item:  https://www.planet.com/data/stac/tanager-core-imagery/coastal...

# %% [markdown]
# ![](https://github.com/user-attachments/assets/da1b044b-69fa-400f-a750-55872c2e2f5e)

# %% [markdown]
# ## Visualize Tanager data
#
# Let's visualize the Tanager data on an interactive map. Specify the bands to visualize. You can visualize the data in the spectral space or the RGB space.

# %%
m = hypercoast.Map()
m.add_tanager(dataset, bands=[100, 60, 50], vmin=0, vmax=120, layer_name="Tanager")
m
# Out:
# Map(center=[52.2499765, 5.2513085], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…

# %% [markdown]
# Alternatively, you can visualize a single band of the Tanager data and specify a colormap.

# %%
m = hypercoast.Map()
m.add_tanager(dataset, bands=[100], colormap="jet", layer_name="Tanager NIR ")
m.add_tanager(dataset, bands=[50], colormap="jet", layer_name="Tanager Blue")
m
# Out:
# Map(center=[52.2499765, 5.2513085], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…

# %% [markdown]
# ## Change band combinations interactively
#
# To change the band combinations interactively, you can use spectral tool to select the bands you want to visualize.

# %%
m = hypercoast.Map()
m.add_tanager(dataset, bands=[100, 60, 50])
m.add("spectral")
m
# Out:
# Map(center=[52.2499765, 5.2513085], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…

# %% [markdown]
# ## Visualize spectral signatures
#
# To visualize the spectral signatures, you can use the `spectral` tool. Simply click on the map to visualize the spectral signatures.

# %%
m = hypercoast.Map()
m.add_tanager(dataset, bands=[100, 60, 50])
m.add("spectral")
m
# Out:
# Map(center=[52.2499765, 5.2513085], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…

# %% [markdown]
# ## Save spectral signatures
#
# To save the spectral signatures, click on the Save button in the spectral tool.
#
# ![](https://github.com/user-attachments/assets/e0c45e07-cdd4-4406-9cd6-152b74b10d42)
